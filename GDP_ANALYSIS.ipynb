# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
os.chdir("C:\Application of software")
os.getcwd()
# Out:
# 'C:\\Application of software'

# %% [markdown]
# ## PART 1 A

# %%
df= pd.read_csv("GDP_data_1.csv")
df
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 5       (% Growth over previous year)  2012-13             8.43
# 6       (% Growth over previous year)  2013-14            12.85
# 7       (% Growth over previous year)  2014-15            13.40
# 8       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# 3           16761.00  198098.00  373920.00     234982.00  40633.00  895027.00
# 4           18784.00  224234.00  413503.00     260776.00  45002.00  994316.00
# 5              13.41       9.56      14.25         12.30    -10.02      17.69
# 6              16.38      13.31      12.30         16.44     -5.77      11.47
# 7              14.79      11.45      17.92         13.69     13.12      10.82
# 8              12.07      13.19      10.59         10.98     10.75      11.09
#
#      Haryana  ...  Telangana   Tripura  Uttar Pradesh  Uttarakhand  \
# 0  297539.00  ...  359433.00  19208.00      724049.00    115523.00
# 1  347032.00  ...  401493.00  21663.00      822903.00    131835.00
# 2  400662.00  ...  452186.00  25593.00      944146.00    149817.00
# 3  437462.00  ...  511178.00  29667.00     1043371.00    161985.00
# 4  485184.00  ...  575631.00       NaN     1153795.00    184091.00
# 5      16.63  ...      11.70     12.78          13.65        14.12
# 6      15.45  ...      12.63     18.14          14.73        13.64
# 7       9.18  ...      13.05     15.92          10.51         8.12
# 8      10.91  ...      12.61       NaN          10.58        13.65
#
#    West Bengal1  Andaman & Nicobar Islands  Chandigarh      Delhi  Puducherry  \
# 0           NaN                    3979.00    18768.00  343767.00    16818.00
# 1           NaN                    4421.00    21609.00  391238.00    18875.00
# 2           NaN                    5159.00    24787.00  443783.00    21870.00
# 3           NaN                    5721.00    27844.00  492424.00    24089.00
# 4           NaN                        NaN    30304.00  551963.00    26533.00
# 5           NaN                      11.13       15.14      13.81       12.23
# 6           NaN                      16.68       14.71      13.43       15.87
# 7           NaN                      10.89       12.33      10.96       10.14
# 8           NaN                        NaN        8.84      12.09       10.15
#
#    All_India GDP
# 0     8736039.00
# 1     9946636.00
# 2    11236635.00
# 3    12433749.00
# 4    13675331.00
# 5          13.86
# 6          12.97
# 7          10.65
# 8           9.99
#
# [9 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 36 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Items  Description         9 non-null      object
#  1   Duration                   9 non-null      object
#  2   Andhra Pradesh             9 non-null      float64
#  3   Arunachal Pradesh          9 non-null      float64
#  4   Assam                      9 non-null      float64
#  5   Bihar                      9 non-null      float64
#  6   Chhattisgarh               9 non-null      float64
#  7   Goa                        9 non-null      float64
#  8   Gujarat                    9 non-null      float64
#  9   Haryana                    9 non-null      float64
#  10  Himachal Pradesh           7 non-null      float64
#  11  Jammu & Kashmir            9 non-null      float64
#  12  Jharkhand                  9 non-null      float64
#  13  Karnataka                  9 non-null      float64
#  14  Kerala                     9 non-null      float64
#  15  Madhya Pradesh             9 non-null      float64
#  16  Maharashtra                7 non-null      float64
#  17  Manipur                    7 non-null      float64
#  18  Meghalaya                  9 non-null      float64
#  19  Mizoram                    7 non-null      float64
#  20  Nagaland                   7 non-null      float64
#  21  Odisha                     9 non-null      float64
#  22  Punjab                     7 non-null      float64
#  23  Rajasthan                  7 non-null      float64
#  24  Sikkim                     9 non-null      float64
#  25  Tamil Nadu                 9 non-null      float64
#  26  Telangana                  9 non-null      float64
#  27  Tripura                    7 non-null      float64
#  28  Uttar Pradesh              9 non-null      float64
#  29  Uttarakhand                9 non-null      float64
#  30  West Bengal1               0 non-null      float64
#  31  Andaman & Nicobar Islands  7 non-null      float64
#  32  Chandigarh                 9 non-null      float64
#  33  Delhi                      9 non-null      float64
#  34  Puducherry                 9 non-null      float64
#  35  All_India GDP              9 non-null      float64
# dtypes: float64(34), object(2)
# memory usage: 2.7+ KB

# %%
df.isna().sum()
# Out:
# Items  Description           0
# Duration                     0
# Andhra Pradesh               0
# Arunachal Pradesh            0
# Assam                        0
# Bihar                        0
# Chhattisgarh                 0
# Goa                          0
# Gujarat                      0
# Haryana                      0
# Himachal Pradesh             2
# Jammu & Kashmir              0
# Jharkhand                    0
# Karnataka                    0
# Kerala                       0
# Madhya Pradesh               0
# Maharashtra                  2
# Manipur                      2
# Meghalaya                    0
# Mizoram                      2
# Nagaland                     2
# Odisha                       0
# Punjab                       2
# Rajasthan                    2
# Sikkim                       0
# Tamil Nadu                   0
# Telangana                    0
# Tripura                      2
# Uttar Pradesh                0
# Uttarakhand                  0
# West Bengal1                 9
# Andaman & Nicobar Islands    2
# Chandigarh                   0
# Delhi                        0
# Puducherry                   0
# All_India GDP                0
# dtype: int64

# %% [markdown]
# ### 1. Calculate the average growth of states for the duration 2013-14, 2014-15 and 2015-16 by taking the mean of the row '(% Growth over previous year)'. ### Compare the calculated values and plot them for the states. Make appropriate transformations, if necessary, to plot the data

# %%
df = df.drop(columns=["West Bengal1"])
df
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 5       (% Growth over previous year)  2012-13             8.43
# 6       (% Growth over previous year)  2013-14            12.85
# 7       (% Growth over previous year)  2014-15            13.40
# 8       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# 3           16761.00  198098.00  373920.00     234982.00  40633.00  895027.00
# 4           18784.00  224234.00  413503.00     260776.00  45002.00  994316.00
# 5              13.41       9.56      14.25         12.30    -10.02      17.69
# 6              16.38      13.31      12.30         16.44     -5.77      11.47
# 7              14.79      11.45      17.92         13.69     13.12      10.82
# 8              12.07      13.19      10.59         10.98     10.75      11.09
#
#      Haryana  ...  Tamil Nadu  Telangana   Tripura  Uttar Pradesh  \
# 0  297539.00  ...   751485.00  359433.00  19208.00      724049.00
# 1  347032.00  ...   855481.00  401493.00  21663.00      822903.00
# 2  400662.00  ...   971090.00  452186.00  25593.00      944146.00
# 3  437462.00  ...  1092564.00  511178.00  29667.00     1043371.00
# 4  485184.00  ...  1212668.00  575631.00       NaN     1153795.00
# 5      16.63  ...       13.84      11.70     12.78          13.65
# 6      15.45  ...       13.51      12.63     18.14          14.73
# 7       9.18  ...       12.51      13.05     15.92          10.51
# 8      10.91  ...       10.99      12.61       NaN          10.58
#
#    Uttarakhand  Andaman & Nicobar Islands  Chandigarh      Delhi  Puducherry  \
# 0    115523.00                    3979.00    18768.00  343767.00    16818.00
# 1    131835.00                    4421.00    21609.00  391238.00    18875.00
# 2    149817.00                    5159.00    24787.00  443783.00    21870.00
# 3    161985.00                    5721.00    27844.00  492424.00    24089.00
# 4    184091.00                        NaN    30304.00  551963.00    26533.00
# 5        14.12                      11.13       15.14      13.81       12.23
# 6        13.64                      16.68       14.71      13.43       15.87
# 7         8.12                      10.89       12.33      10.96       10.14
# 8        13.65                        NaN        8.84      12.09       10.15
#
#    All_India GDP
# 0     8736039.00
# 1     9946636.00
# 2    11236635.00
# 3    12433749.00
# 4    13675331.00
# 5          13.86
# 6          12.97
# 7          10.65
# 8           9.99
#
# [9 rows x 35 columns]

# %%
selected_years = ['2013-14', '2014-15', '2015-16']
df2 = df[df["Duration"].isin(selected_years)]
df2
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2013-14            12.85
# 7       (% Growth over previous year)  2014-15            13.40
# 8       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# 3           16761.00  198098.00  373920.00     234982.00  40633.00  895027.00
# 4           18784.00  224234.00  413503.00     260776.00  45002.00  994316.00
# 6              16.38      13.31      12.30         16.44     -5.77      11.47
# 7              14.79      11.45      17.92         13.69     13.12      10.82
# 8              12.07      13.19      10.59         10.98     10.75      11.09
#
#      Haryana  ...  Tamil Nadu  Telangana   Tripura  Uttar Pradesh  \
# 2  400662.00  ...   971090.00  452186.00  25593.00      944146.00
# 3  437462.00  ...  1092564.00  511178.00  29667.00     1043371.00
# 4  485184.00  ...  1212668.00  575631.00       NaN     1153795.00
# 6      15.45  ...       13.51      12.63     18.14          14.73
# 7       9.18  ...       12.51      13.05     15.92          10.51
# 8      10.91  ...       10.99      12.61       NaN          10.58
#
#    Uttarakhand  Andaman & Nicobar Islands  Chandigarh      Delhi  Puducherry  \
# 2    149817.00                    5159.00    24787.00  443783.00    21870.00
# 3    161985.00                    5721.00    27844.00  492424.00    24089.00
# 4    184091.00                        NaN    30304.00  551963.00    26533.00
# 6        13.64                      16.68       14.71      13.43       15.87
# 7         8.12                      10.89       12.33      10.96       10.14
# 8        13.65                        NaN        8.84      12.09       10.15
#
#    All_India GDP
# 2    11236635.00
# 3    12433749.00
# 4    13675331.00
# 6          12.97
# 7          10.65
# 8           9.99
#
# [6 rows x 35 columns]

# %%
df2 = df2[df2["Items  Description"] == "(% Growth over previous year)"]
state_columns = [col for col in df.columns if col not in ["Duration", "Items  Description"]]
average_growth = df2[state_columns].mean()
print("Average percentage growth across each state:")
print(average_growth)
# Out:
# Average percentage growth across each state:
# Andhra Pradesh               14.033333
# Arunachal Pradesh            14.413333
# Assam                        12.650000
# Bihar                        13.603333
# Chhattisgarh                 13.703333
# Goa                           6.033333
# Gujarat                      11.126667
# Haryana                      11.846667
# Himachal Pradesh             12.280000
# Jammu & Kashmir              10.900000
# Jharkhand                    11.500000
# Karnataka                    14.120000
# Kerala                       12.583333
# Madhya Pradesh               12.626667
# Maharashtra                  11.260000
# Manipur                      14.610000
# Meghalaya                     6.953333
# Mizoram                      17.700000
# Nagaland                     16.415000
# Odisha                        9.836667
# Punjab                       11.185000
# Rajasthan                    11.320000
# Sikkim                       10.486667
# Tamil Nadu                   12.336667
# Telangana                    12.763333
# Tripura                      17.030000
# Uttar Pradesh                11.940000
# Uttarakhand                  11.803333
# Andaman & Nicobar Islands    13.785000
# Chandigarh                   11.960000
# Delhi                        12.160000
# Puducherry                   12.053333
# All_India GDP                11.203333
# dtype: float64

# %%
# Plotting the data
plt.figure(figsize=(18, 15))
average_growth.plot(kind='bar', color='skyblue', edgecolor='black')

# Adding labels and title
plt.title("Average Percentage Growth Across States", fontsize=14)
plt.xlabel("States", fontsize=12)
plt.ylabel("Average Growth (%)", fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2. Which states have been growing consistently fast, and which ones have been struggling?

# %%
#df2['Growth Variation'] = df2[['%Growth-2013-14','%Growth-2014-15','%Growth-2015-16']].std(axis=1)
# Filter rows for "Percentage Growth"
growth_df = df2[df2['Items  Description'] == "(% Growth over previous year)"].drop(columns=["Items  Description", "Duration"])

# Determine consistent growth and struggling states
def check_growth_trend(values):
    # Check if all values are positive and increasing
    return all(x > 0 for x in values) and all(values[i] <= values[i + 1] for i in range(len(values) - 1))

growth_analysis = {
    state: "Consistently Growing" if check_growth_trend(growth_df[state].values) else "Struggling"
    for state in growth_df.columns
}

# Display the analysis
for state, status in growth_analysis.items():
 print(f"{state}: {status}")
# Out:
# Andhra Pradesh : Consistently Growing
# Arunachal Pradesh: Struggling
# Assam: Struggling
# Bihar: Struggling
# Chhattisgarh: Struggling
# Goa: Struggling
# Gujarat: Struggling
# Haryana: Struggling
# Himachal Pradesh: Struggling
# Jammu & Kashmir: Struggling
# Jharkhand: Struggling
# Karnataka: Struggling
# Kerala: Struggling
# Madhya Pradesh: Struggling
# Maharashtra: Struggling
# Manipur: Struggling
# Meghalaya: Consistently Growing
# Mizoram: Struggling
# Nagaland: Struggling
# Odisha: Struggling
# Punjab: Struggling
# Rajasthan: Struggling
# Sikkim: Struggling
# Tamil Nadu: Struggling
# Telangana: Struggling
# Tripura: Struggling
# Uttar Pradesh: Struggling
# Uttarakhand: Struggling
# Andaman & Nicobar Islands: Struggling
# Chandigarh: Struggling
# Delhi: Struggling
# Puducherry: Struggling
# All_India GDP: Struggling

# %% [markdown]
# ### 3.Plot the total GDP of the states for the year 2015-16:

# %%
# Filter for "Percentage Growth" rows
percentage_growth = df2[df2["Items  Description"] == "(% Growth over previous year)"]

# Calculate the average growth rate for Karnataka and India
karnataka_avg_growth = percentage_growth["Karnataka"].mean()
india_avg_growth = percentage_growth["All_India GDP"].mean()

# Comparison
difference = karnataka_avg_growth - india_avg_growth
ratio = karnataka_avg_growth / india_avg_growth

print(f"Average Growth Rate of Karnataka: {karnataka_avg_growth:.2f}%")
print(f"Average Growth Rate of India: {india_avg_growth:.2f}%")
print(f"Difference in Growth Rate: {difference:.2f}%")
print(f"Ratio of Karnataka to India Growth: {ratio:.2f}")
# Out:
# Average Growth Rate of Karnataka: 14.12%
# Average Growth Rate of India: 11.20%
# Difference in Growth Rate: 2.92%
# Ratio of Karnataka to India Growth: 1.26

# %% [markdown]
# ### Identify the top 5 and the bottom 5 states based on total GDP.

# %%
# Step 1: Filter for year 2015-16 and GSDP
filtered_df = df[(df["Duration"] == '2015-16') & (df["Items  Description"] == "GSDP - CURRENT PRICES (` in Crore)")]
filtered_df.set_index('Items  Description', inplace= True )

# %%
# Step 2: Drop 'Year' and 'Item Description' columns and transpose
gsdp_data = filtered_df.drop(columns=["Duration"]).transpose()
gsdp = gsdp_data.dropna()
state_gsdp = gsdp.drop('All_India GDP')

# %%
# Step 3: Sort by GSDP
sorted_gsdp = state_gsdp .sort_values(by= 'GSDP - CURRENT PRICES (` in Crore)', ascending=False)

# Step 4: Select top 5 and bottom 5 states
top_5 = sorted_gsdp.head(5)
bottom_5 = sorted_gsdp.tail(5)

print("Top 5 States by GSDP in 2015-16:")
print(top_5)

print("\nBottom 5 States by GSDP in 2015-16:")
print(bottom_5)
# Out:
# Top 5 States by GSDP in 2015-16:
# Items  Description  GSDP - CURRENT PRICES (` in Crore)
# Tamil Nadu                                   1212668.0
# Uttar Pradesh                                1153795.0
# Karnataka                                    1027068.0
# Gujarat                                       994316.0
# Andhra Pradesh                                609934.0
#
# Bottom 5 States by GSDP in 2015-16:
# Items  Description  GSDP - CURRENT PRICES (` in Crore)
# Chandigarh                                     30304.0
# Meghalaya                                      26745.0
# Puducherry                                     26533.0
# Arunachal Pradesh                              18784.0
# Sikkim                                         16637.0

# %%
# Step 6: Plotting the top 5 and bottom 5 states
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Top 5 States Plot
ax[0].barh(top_5.index, top_5['GSDP - CURRENT PRICES (` in Crore)'], color='green')
ax[0].set_title('Top 5 States by GSDP (2015-16)')
ax[0].set_xlabel('GSDP')
ax[0].set_ylabel('States')

# Bottom 5 States Plot
ax[1].barh(bottom_5.index, bottom_5['GSDP - CURRENT PRICES (` in Crore)'], color='red')
ax[1].set_title('Bottom 5 States by GSDP (2015-16)')
ax[1].set_xlabel('GSDP')
ax[1].set_ylabel('States')

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## PART- 1 - B

# %%
pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\layashree s\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: openpyxl in c:\users\layashree s\anaconda3\lib\site-packages (3.0.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\layashree s\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\layashree s\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\layashree s\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\layashree s\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: et_xmlfile in c:\users\layashree s\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\layashree s\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os

# Path to the folder containing the CSV files
folder_path = "C:\Application of software\All States"

# List to store individual dataframes
dfs = []

# Loop through all files in the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith('.csv'):  # Check if the file is a CSV
        file_path = os.path.join(folder_path, file_name)
        try:
            # Try reading the CSV file with UTF-8 encoding
            df = pd.read_csv(file_path, encoding='utf-8')
        except UnicodeDecodeError:
            # If UTF-8 fails, use a fallback encoding
            df = pd.read_csv(file_path, encoding='latin1')
        dfs.append(df)

# Concatenate all dataframes into a single dataframe
final_df = pd.concat(dfs, ignore_index=True)

# Display the first few rows of the final dataframe
print(final_df.head())

# Optionally, save the combined dataframe to a new CSV file
final_df.to_csv('combined_data.csv', index=False)
# Out:
#   S.No.                               Item          State    2011-12  \
# 0     1  Agriculture, forestry and fishing  Andra Pradesh  9400805.0
# 1   1.1                              Crops  Andra Pradesh  5204052.0
# 2   1.2                          Livestock  Andra Pradesh  2758776.0
# 3   1.3               Forestry and logging  Andra Pradesh   250314.0
# 4   1.4            Fishing and aquaculture  Andra Pradesh  1187663.0
#
#       2012-13     2013-14     2014-15     2015-16     2016-17
# 0  11186428.0  12895568.0  14819416.0  17326726.0  20386004.0
# 1   6123041.0   7114707.0   7893514.0   8644285.0   9717089.0
# 2   3358438.0   3643026.0   4309078.0   5155487.0   5979648.0
# 3    253029.0    280493.0    346160.0    340550.0    335487.0
# 4   1451920.0   1857342.0   2270664.0   3186404.0   4353780.0

# %%
excluded_columns = ['2011-12', '2012-13','2013-14','2015-16','2016-17']
df= final_df.drop(columns=excluded_columns)

# %%
df
# Out:
#     S.No.                               Item          State      2014-15
# 0       1  Agriculture, forestry and fishing  Andra Pradesh   14819416.0
# 1     1.1                              Crops  Andra Pradesh    7893514.0
# 2     1.2                          Livestock  Andra Pradesh    4309078.0
# 3     1.3               Forestry and logging  Andra Pradesh     346160.0
# 4     1.4            Fishing and aquaculture  Andra Pradesh    2270664.0
# ..    ...                                ...            ...          ...
# 886    13                  Taxes on Products  Uttar Pradesh   10107396.0
# 887    14              Subsidies on products  Uttar Pradesh    3287219.0
# 888    15       Gross State Domestic Product  Uttar Pradesh  104337115.0
# 889    16                    Population (00)  Uttar Pradesh    2109940.0
# 890    17              Per Capita GSDP (Rs.)  Uttar Pradesh      49450.0
#
# [891 rows x 4 columns]

# %%
# Filter the dataframe for "GDP per capita" in the Item column
gdp_df = df[df['Item'] == 'Per Capita GSDP (Rs.)']
gdp_df
# Out:
#     S.No.                   Item              State   2014-15
# 32     17  Per Capita GSDP (Rs.)      Andra Pradesh  104977.0
# 65     17  Per Capita GSDP (Rs.)  Arunachal Pradesh  112718.0
# 98     17  Per Capita GSDP (Rs.)              Assam   60621.0
# 131    17  Per Capita GSDP (Rs.)              Bihar   33954.0
# 164    17  Per Capita GSDP (Rs.)      Chhattisgarh-   86860.0
# 197    17  Per Capita GSDP (Rs.)                Goa  271793.0
# 230    17  Per Capita GSDP (Rs.)            Gujarat  141263.0
# 263    17  Per Capita GSDP (Rs.)            Haryana  164077.0
# 296    17  Per Capita GSDP (Rs.)   Himachal Pradesh  147330.0
# 329    17  Per Capita GSDP (Rs.)          Jharkhand   62091.0
# 362    17  Per Capita GSDP (Rs.)          Karnataka  145141.0
# 395    17  Per Capita GSDP (Rs.)             Kerala  154778.0
# 428    17  Per Capita GSDP (Rs.)     Madhya Pradesh   62989.0
# 461    17  Per Capita GSDP (Rs.)        Maharashtra  152853.0
# 494    17  Per Capita GSDP (Rs.)            Manipur   58442.0
# 527    17  Per Capita GSDP (Rs.)          Meghalaya   76228.0
# 560    17  Per Capita GSDP (Rs.)            Mizoram   97687.0
# 593    17  Per Capita GSDP (Rs.)           Nagaland   89607.0
# 626    17  Per Capita GSDP (Rs.)             Odisha   73979.0
# 659    17  Per Capita GSDP (Rs.)             Punjab  126606.0
# 692    17  Per Capita GSDP (Rs.)          Rajasthan   84837.0
# 725    17  Per Capita GSDP (Rs.)             Sikkim  240274.0
# 758    17  Per Capita GSDP (Rs.)         Tamil Nadu  146503.0
# 791    17  Per Capita GSDP (Rs.)          Telangana  139035.0
# 824    17  Per Capita GSDP (Rs.)            Tripura   77358.0
# 857    17  Per Capita GSDP (Rs.)        Uttarakhand  153076.0
# 890    17  Per Capita GSDP (Rs.)      Uttar Pradesh   49450.0

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27 entries, 32 to 890
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.No.    27 non-null     object
#  1   Item     27 non-null     object
#  2   State    27 non-null     object
#  3   2014-15  27 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 1.1+ KB

# %% [markdown]
# ### Plot the GDP per capita for all the states.

# %%
# Plotting the GDP per capita for all states
plt.figure(figsize=(15, 10))
plt.bar(gdp_df['State'], gdp_df['2014-15'], color='skyblue')

# Add labels and title
plt.xlabel('State', fontsize=12)
plt.ylabel('GDP per Capita', fontsize=12)
plt.title('GDP per Capita by State', fontsize=14)
plt.xticks(rotation=90)  # Rotate state names for better readability
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### Identify the top 5 and the bottom 5 states based on the GDP per capita.

# %%
# Sort the dataframe by 'Value' (GDP per capita)
sorted_gdp_df = gdp_df.sort_values(by='2014-15', ascending=False)

# Get the top 5 and bottom 5 states based on GDP per capita
top_5_states = sorted_gdp_df.head(5)
bottom_5_states = sorted_gdp_df.tail(5)

# Combine the top 5 and bottom 5 states into one dataframe for easy plotting
combined_df = pd.concat([top_5_states, bottom_5_states])

# Plotting the GDP per capita for top 5 and bottom 5 states
plt.figure(figsize=(10, 6))

# Create a bar plot for both top and bottom 5 states
plt.bar(combined_df['State'], combined_df['2014-15'], color=['green' if x in top_5_states['State'].values else 'red' for x in combined_df['State']])

# Add labels and title
plt.xlabel('State', fontsize=12)
plt.ylabel('GDP per Capita', fontsize=12)
plt.title('Top 5 and Bottom 5 States by GDP per Capita', fontsize=14)
plt.xticks(rotation=45)  # Rotate state names for better readability
plt.tight_layout()

# Show the plot
plt.show()

# Optional: Print the top 5 and bottom 5 states for reference
print("Top 5 States by GDP per Capita:")
print(top_5_states[['State', '2014-15']])

print("\nBottom 5 States by GDP per Capita:")
print(bottom_5_states[['State', '2014-15']])
# Out:
# Top 5 States by GDP per Capita:
#            State   2014-15
# 197          Goa  271793.0
# 725       Sikkim  240274.0
# 263      Haryana  164077.0
# 395       Kerala  154778.0
# 857  Uttarakhand  153076.0
#
# Bottom 5 States by GDP per Capita:
#              State  2014-15
# 329      Jharkhand  62091.0
# 98           Assam  60621.0
# 494        Manipur  58442.0
# 890  Uttar Pradesh  49450.0
# 131          Bihar  33954.0

# %% [markdown]
# ### Find the ratio of the highest per capita GDP to the lowest per capita GDP.

# %%
# Find the highest and lowest GDP per capita
max_gdp = gdp_df['2014-15'].max()
min_gdp = gdp_df['2014-15'].min()

# Calculate the ratio of highest to lowest GDP per capita
gdp_ratio = max_gdp / min_gdp

# Print the result
print(f"The ratio of the highest per capita GDP ({max_gdp}) to the lowest per capita GDP ({min_gdp}) is: {gdp_ratio}")
# Out:
# The ratio of the highest per capita GDP (271793.0) to the lowest per capita GDP (33954.0) is: 8.004741709371503

# %% [markdown]
# ### •	Plot the percentage contribution of the primary, secondary and tertiary sectors as a percentage of the total GDP for all the states.

# %%
# Pivot the data to have sectors as columns for each state
pivot_df = df.pivot(index='State', columns='Item', values='2014-15')

# Calculate the total GDP for each state
pivot_df['Total_GDP'] = pivot_df.sum(axis=1)

# Calculate the percentage contribution of each sector
pivot_df_percent = pivot_df[['Primary', 'Secondary', 'Tertiary']].div(pivot_df['Total_GDP'], axis=0) * 100

# Plot the data
pivot_df_percent.plot(kind='bar', stacked=True, figsize=(18, 10))
plt.title('Percentage Contribution of Primary, Secondary, and Tertiary Sectors to GDP (2014-15)')
plt.ylabel('Percentage Contribution')
plt.xlabel('State')
plt.xticks(rotation=45)
plt.legend(title='Sector', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### •	Categorise the states into four groups based on the GDP per capita (C1, C2, C3, C4, where C1 would have the highest per capita GDP and C4, the lowest). The quantile values are (0.20,0.5, 0.85, 1), i.e., the states lying between the 85th and the 100th percentile are in C1; those between the 50th and the 85th percentiles are in C2, and so on.

# %%
# Calculate quantiles
quantiles = df['2014-15'].quantile([0.20, 0.50, 0.85, 1.0])

# Define function to assign categories based on quantile ranges
def categorize_gdp(gdp):
    if gdp >= quantiles[0.85]:
        return 'C1'  # 85th-100th percentile
    elif gdp >= quantiles[0.50]:
        return 'C2'  # 50th-85th percentile
    elif gdp >= quantiles[0.20]:
        return 'C3'  # 20th-50th percentile
    else:
        return 'C4'  # 0-20th percentile

# Apply the function to categorize the states
df['GDP_Category'] = df['2014-15'].apply(categorize_gdp)

df
# Out:
#     S.No.                               Item          State      2014-15  \
# 0       1  Agriculture, forestry and fishing  Andra Pradesh   14819416.0
# 1     1.1                              Crops  Andra Pradesh    7893514.0
# 2     1.2                          Livestock  Andra Pradesh    4309078.0
# 3     1.3               Forestry and logging  Andra Pradesh     346160.0
# 4     1.4            Fishing and aquaculture  Andra Pradesh    2270664.0
# ..    ...                                ...            ...          ...
# 886    13                  Taxes on Products  Uttar Pradesh   10107396.0
# 887    14              Subsidies on products  Uttar Pradesh    3287219.0
# 888    15       Gross State Domestic Product  Uttar Pradesh  104337115.0
# 889    16                    Population (00)  Uttar Pradesh    2109940.0
# 890    17              Per Capita GSDP (Rs.)  Uttar Pradesh      49450.0
#
#     GDP_Category
# 0             C1
# 1             C1
# 2             C2
# 3             C3
# 4             C2
# ..           ...
# 886           C1
# 887           C2
# 888           C1
# 889           C2
# 890           C4
#
# [891 rows x 5 columns]

# %% [markdown]
# ### Find the top sectors (such as agriculture, forestry and fishing, crops, manufacturing etc., not primary, secondary and tertiary) that contribute to approximately 80% of the GSDP of each category.

# %%
exclude_rows = ['Primary', 'Secondary', 'Tertiary', 'TOTAL GSVA at basic prices',
                'Taxes on Products', 'Subsidies on products', 'Gross State Domestic Product',
                'Population (00)', 'Per Capita GSDP (Rs.)']
df_filtered = df[~df['Item'].isin(exclude_rows)]

df_filtered
# Out:
#     S.No.                                               Item          State  \
# 0       1                  Agriculture, forestry and fishing  Andra Pradesh
# 1     1.1                                              Crops  Andra Pradesh
# 2     1.2                                          Livestock  Andra Pradesh
# 3     1.3                               Forestry and logging  Andra Pradesh
# 4     1.4                            Fishing and aquaculture  Andra Pradesh
# ..    ...                                                ...            ...
# 879   7.7   Communication & services related to broadcasting  Uttar Pradesh
# 880     8                                 Financial services  Uttar Pradesh
# 881     9  Real estate, ownership of dwelling & professio...  Uttar Pradesh
# 882    10                              Public administration  Uttar Pradesh
# 883    11                                     Other services  Uttar Pradesh
#
#         2014-15 GDP_Category
# 0    14819416.0           C1
# 1     7893514.0           C1
# 2     4309078.0           C2
# 3      346160.0           C3
# 4     2270664.0           C2
# ..          ...          ...
# 879   1914737.0           C2
# 880   3392275.0           C2
# 881  14548185.0           C1
# 882   6152124.0           C2
# 883   5034623.0           C2
#
# [648 rows x 5 columns]

# %%
# Clean column names to ensure they are correctly formatted
df_filtered.columns = df_filtered.columns.str.strip()

# Verify column names to check for issues
print("Column names:", df_filtered.columns)
# Group by GDP_category, then by Item to calculate the sum of GSDP (2014-15 column)
gdp_sum = df_filtered.groupby(['GDP_Category', 'Item'], as_index=False)['2014-15'].sum()

# Function to find sectors contributing to 80% of the GSDP for each category
def find_top_sectors_for_80(df_filtered, gdp_column='2014-15', target_percentage=80):
    result = []
    
    # Loop through each GDP category
    for category in df_filtered['GDP_Category'].unique():
        category_data = df_filtered[df_filtered['GDP_Category'] == category]
        
        # Sort sectors by GSDP contribution in descending order
        category_data = category_data.sort_values(by=gdp_column, ascending=False)
        
        # Calculate the cumulative sum of GSDP
        category_data['cumulative_sum'] = category_data[gdp_column].cumsum()
        
        # Calculate total GSDP for the category
        total_gdp = category_data[gdp_column].sum()
        
        # Find sectors contributing to 80% of total GSDP
        threshold = total_gdp * target_percentage / 100
        top_sectors = category_data[category_data['cumulative_sum'] <= threshold]
        
        result.append(top_sectors[['GDP_Category', 'Item', gdp_column]])
    
    # Concatenate the results from each category into a final dataframe
    final_result = pd.concat(result, ignore_index=True)
    return final_result

# Get the top sectors contributing to 80% of the GSDP
top_sectors_df = find_top_sectors_for_80(gdp_sum)

top_sectors_df
# Out:
# Column names: Index(['S.No.', 'Item', 'State', '2014-15', 'GDP_Category'], dtype='object')
#    GDP_Category                                               Item  \
# 0            C1                  Agriculture, forestry and fishing
# 1            C1                                      Manufacturing
# 2            C1  Real estate, ownership of dwelling & professio...
# 3            C1                                              Crops
# 4            C2                                     Other services
# 5            C2                                      Manufacturing
# 6            C2  Transport, storage, communication & services r...
# 7            C2                                       Construction
# 8            C2                            Trade & repair services
# 9            C2              Trade, repair, hotels and restaurants
# 10           C2  Real estate, ownership of dwelling & professio...
# 11           C2                                          Livestock
# 12           C2                                              Crops
# 13           C2                              Public administration
# 14           C2                  Agriculture, forestry and fishing
# 15           C3                               Forestry and logging
# 16           C3                            Fishing and aquaculture
# 17           C3                                           Railways
# 18           C3   Communication & services related to broadcasting
# 19           C3  Electricity, gas, water supply & other utility...
# 20           C3                              Public administration
# 21           C3                               Hotels & restaurants
# 22           C3                                 Financial services
# 23           C3                  Agriculture, forestry and fishing
# 24           C3              Trade, repair, hotels and restaurants
# 25           C3                            Trade & repair services
# 26           C3                                              Crops
# 27           C3                                     Road transport
# 28           C4                                            Storage
# 29           C4                   Services incidental to transport
# 30           C4                                      Air transport
# 31           C4                                     Road transport
# 32           C4                                 Financial services
# 33           C4   Communication & services related to broadcasting
# 34           C4                               Forestry and logging
# 35           C4                            Fishing and aquaculture
# 36           C4  Transport, storage, communication & services r...
# 37           C4                                          Livestock
# 38           C4                                    Water transport
# 39           C4                               Mining and quarrying
#
#         2014-15
# 0   150979339.0
# 1   109635039.0
# 2    96341681.0
# 3    73261566.0
# 4    60332388.0
# 5    59030666.0
# 6    57925987.0
# 7    56322147.0
# 8    55612121.0
# 9    51644169.0
# 10   49675648.0
# 11   44939808.0
# 12   43247560.0
# 13   40332873.0
# 14   34876785.0
# 15    6460577.0
# 16    6414262.0
# 17    5320367.0
# 18    4378105.0
# 19    3348231.0
# 20    3220037.0
# 21    2906623.0
# 22    2901412.0
# 23    2706639.0
# 24    2359434.0
# 25    2084939.0
# 26    2010855.0
# 27    1999335.0
# 28     304592.0
# 29     285976.0
# 30     233824.0
# 31     225127.0
# 32     224253.0
# 33     213413.0
# 34     175033.0
# 35     141941.0
# 36     135137.0
# 37     131456.0
# 38     127619.0
# 39     121586.0

# %% [markdown]
# ### plot the contribution of the sub-sectors as a percentage of the GSDP of each category.

# %%
# Group by GDP_category and Item, then calculate the sum of GSDP for each Item within each GDP_category
gdp_sum = df_filtered.groupby(['GDP_Category', 'Item'], as_index=False)['2014-15'].sum()

# Calculate total GSDP for each GDP_category
gdp_sum['Total_GSDP'] = gdp_sum.groupby('GDP_Category')['2014-15'].transform('sum')

# Calculate the percentage contribution of each Item to the total GSDP for that GDP_category
gdp_sum['Percentage_Contribution'] = (gdp_sum['2014-15'] / gdp_sum['Total_GSDP']) * 100

# Plot the contribution as a bar plot
plt.figure(figsize=(20, 10))
for category in gdp_sum['GDP_Category'].unique():
    category_data = gdp_sum[gdp_sum['GDP_Category'] == category]
    plt.bar(category_data['Item'], category_data['Percentage_Contribution'], label=f'Category {category}')

plt.title('Contribution of Sub-Sectors to GSDP by Category')
plt.xlabel('Sub-Sectors (Items)')
plt.ylabel('Percentage Contribution to GSDP')
plt.xticks(rotation=90)
plt.legend(title='GDP Category')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### How does the GDP distribution of the top states (C1) differ from the others?

# %%
import seaborn as sns


# Group by GDP_category and State to calculate the total GSDP (2014-15 column)
gdp_sum_state = df_filtered.groupby(['GDP_Category', 'State'], as_index=False)['2014-15'].sum()

# Separate the data for category C1 and others
c1_states = gdp_sum_state[gdp_sum_state['GDP_Category'] == 'C1']
other_states = gdp_sum_state[gdp_sum_state['GDP_Category'] != 'C1']

# Combine C1 and other states for comparison
gdp_sum_state['Category_Comparison'] = gdp_sum_state['GDP_Category'].apply(lambda x: 'C1' if x == 'C1' else 'Other')

# Plot the distribution using a boxplot for better comparison
plt.figure(figsize=(10, 6))
sns.boxplot(x='Category_Comparison', y='2014-15', data=gdp_sum_state)
plt.title('GDP Distribution of Top States (C1) vs Others')
plt.xlabel('GDP Category')
plt.ylabel('GSDP (2014-15)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part-II: GDP and Education Dropout Rates

# %%
df3  = pd.read_csv("GDP_data_2.csv")

# %%
df3
# Out:
#             1 Level of Education - State  Primary - 2012-2013  \
# 0           1              A & N Islands                 0.68
# 1           2             Andhra Pradesh                 3.18
# 2           3          Arunachal Pradesh                15.16
# 3           4                      Assam                 6.24
# 4           5                      Bihar                  NaN
# 5           6                 Chandigarh                  NaN
# 6           7                Chhatisgarh                 4.14
# 7           8       Dadra & Nagar Haveli                  NaN
# 8           9                Daman & Diu                  NaN
# 9          10                      Delhi                  NaN
# 10         11                        Goa                  NaN
# 11         12                    Gujarat                 0.74
# 12         13                    Haryana                 1.29
# 13         14           Himachal Pradesh                 0.45
# 14         15          Jammu and Kashmir                 6.30
# 15         16                  Jharkhand                 7.21
# 16         17                  Karnataka                 2.97
# 17         18                     Kerala                  NaN
# 18         19                Lakshadweep                 2.50
# 19         20             Madhya Pradesh                 6.11
# 20         21                Maharashtra                 0.97
# 21         22                    Manipur                 9.86
# 22         23                  Meghalaya                10.14
# 23         24                    Mizoram                24.11
# 24         25                   Nagaland                 7.07
# 25         26                     Odisha                 3.56
# 26         27                 Puducherry                 0.34
# 27         28                     Punjab                 1.99
# 28         29                  Rajasthan                 7.97
# 29         30                     Sikkim                 3.60
# 30         31                 Tamil Nadu                 4.06
# 31         32                  Telangana                  NaN
# 32         33                    Tripura                 2.22
# 33         34              Uttar Pradesh                10.28
# 34         35                 Uttrakhand                 1.16
# 35         36                West Bengal                 6.30
# 36  All India                  All India                 4.67
#
#     Primary - 2013-2014  Primary - 2014-2015  Upper Primary - 2012-2013  \
# 0                  1.21                 0.51                       1.23
# 1                  4.35                 6.72                       3.36
# 2                 10.89                10.82                       7.47
# 3                  7.44                15.36                       7.20
# 4                  2.09                  NaN                        NaN
# 5                   NaN                  NaN                       0.10
# 6                  1.42                 2.91                       5.42
# 7                  1.57                 1.47                       3.38
# 8                  0.85                 1.11                        NaN
# 9                   NaN                  NaN                        NaN
# 10                 0.20                 0.73                        NaN
# 11                 0.76                 0.89                       5.20
# 12                 0.41                 5.61                       0.46
# 13                 0.46                 0.64                       0.51
# 14                 5.46                 6.79                       5.52
# 15                 6.41                 5.48                       5.47
# 16                 2.32                 2.02                       5.05
# 17                  NaN                  NaN                        NaN
# 18                  NaN                  NaN                       0.29
# 19                10.14                 6.59                       8.53
# 20                 0.55                 1.26                       1.74
# 21                18.00                 9.66                       6.06
# 22                10.34                 9.46                       7.85
# 23                12.96                10.10                      19.28
# 24                19.41                 5.61                       9.83
# 25                 2.94                 2.86                       3.81
# 26                 0.66                 0.37                       0.68
# 27                 1.29                 3.05                       2.78
# 28                 8.39                 5.02                       4.42
# 29                 4.57                 2.27                       3.15
# 30                 0.46                  NaN                       1.24
# 31                 5.81                 2.08                        NaN
# 32                 3.58                 1.28                       3.08
# 33                 7.08                 8.58                       1.06
# 34                 3.07                 4.04                       0.13
# 35                 2.91                 1.47                       5.18
# 36                 4.34                 4.13                       3.13
#
#     Upper Primary - 2013-2014  Upper Primary - 2014-2015  \
# 0                        0.51                       1.69
# 1                        3.78                       5.20
# 2                        5.59                       6.71
# 3                        7.05                      10.51
# 4                        2.98                       4.08
# 5                        1.08                       0.44
# 6                        3.80                       5.85
# 7                        4.13                       4.02
# 8                        3.58                       3.11
# 9                        2.78                       0.76
# 10                        NaN                       0.07
# 11                       5.55                       6.41
# 12                       2.55                       5.81
# 13                       0.78                       0.87
# 14                       4.30                       5.44
# 15                       7.42                       8.99
# 16                       2.51                       3.85
# 17                        NaN                        NaN
# 18                       1.86                       2.78
# 19                      11.70                       9.20
# 20                       0.61                       1.79
# 21                       7.02                       4.20
# 22                       6.84                       6.52
# 23                       6.02                       4.78
# 24                      17.86                       7.92
# 25                       2.80                       3.81
# 26                       0.60                       0.56
# 27                       2.85                       3.22
# 28                       6.03                       3.07
# 29                       5.14                       1.57
# 30                       4.52                        NaN
# 31                       4.71                       2.30
# 32                       2.72                       1.99
# 33                       0.53                       2.70
# 34                       1.68                       1.19
# 35                       4.31                       4.30
# 36                       3.77                       4.03
#
#     Secondary - 2012-2013  Secondary - 2013-2014  Secondary - 2014-2015  \
# 0                    5.56                   7.20                  9.870
# 1                   12.72                  12.65                 15.710
# 2                   12.93                  14.49                 17.110
# 3                   26.77                  30.43                 27.060
# 4                   30.14                  25.33                 25.900
# 5                     NaN                    NaN                    NaN
# 6                   14.86                  23.41                 21.260
# 7                   24.41                  28.59                 16.770
# 8                   11.52                  19.86                 32.270
# 9                    5.32                   8.90                 11.810
# 10                   7.96                   9.58                 11.150
# 11                  13.55                  21.61                 25.040
# 12                   8.98                  12.51                 15.890
# 13                   8.37                   9.09                  6.070
# 14                  17.33                  15.36                 17.280
# 15                  18.50                  23.15                 24.000
# 16                  39.92                  27.57                 26.180
# 17                   9.45                  14.46                 12.320
# 18                   7.68                   8.03                  6.763
# 19                  13.63                  26.47                 24.770
# 20                  16.20                  14.47                 12.870
# 21                   9.75                  13.81                 14.380
# 22                  26.03                  24.75                 20.520
# 23                  21.42                  18.70                 21.880
# 24                  26.51                  35.11                 18.230
# 25                  49.86                  49.48                 29.560
# 26                  15.21                  14.24                 12.190
# 27                   9.80                   8.83                  8.860
# 28                  13.65                  18.77                 13.480
# 29                   9.23                  12.89                 15.890
# 30                  10.20                  12.20                  8.100
# 31                    NaN                  17.43                 15.530
# 32                  25.50                  25.09                 28.420
# 33                    NaN                   7.30                 10.220
# 34                   9.68                   8.70                 10.400
# 35                  17.30                  18.34                 17.800
# 36                  14.54                  17.86                 17.060
#
#     Senior Secondary - 2012-2013  Senior Secondary - 2013-2014  \
# 0                          14.14                         15.87
# 1                           0.35                         11.79
# 2                           5.11                         17.07
# 3                           4.69                          7.24
# 4                            NaN                           NaN
# 5                          13.65                         11.28
# 6                            NaN                           NaN
# 7                           9.65                          6.24
# 8                           1.26                          9.86
# 9                          14.47                         16.25
# 10                         11.26                         13.36
# 11                          0.46                          7.83
# 12                           NaN                          2.18
# 13                          9.02                          7.07
# 14                         10.66                          7.64
# 15                           NaN                           NaN
# 16                         15.33                           NaN
# 17                           NaN                          6.40
# 18                          6.59                          2.82
# 19                           NaN                          1.55
# 20                          3.20                          3.34
# 21                          7.93                          3.20
# 22                           NaN                           NaN
# 23                           NaN                           NaN
# 24                         18.29                         14.19
# 25                           NaN                           NaN
# 26                          5.25                         11.16
# 27                          8.28                          5.81
# 28                           NaN                           NaN
# 29                          8.10                         12.91
# 30                          1.87                          4.44
# 31                           NaN                         13.43
# 32                          8.87                          9.11
# 33                           NaN                           NaN
# 34                          1.59                           NaN
# 35                          8.13                          7.90
# 36                           NaN                          1.54
#
#     Senior Secondary - 2014-2015
# 0                          16.93
# 1                            NaN
# 2                          18.42
# 3                            NaN
# 4                            NaN
# 5                          10.55
# 6                           2.76
# 7                           9.47
# 8                          40.48
# 9                          17.32
# 10                         13.91
# 11                          7.04
# 12                          5.75
# 13                          7.41
# 14                         12.65
# 15                          3.41
# 16                          1.96
# 17                          0.47
# 18                          3.12
# 19                           NaN
# 20                          1.83
# 21                           NaN
# 22                           NaN
# 23                          6.91
# 24                          6.97
# 25                           NaN
# 26                          4.50
# 27                          5.83
# 28                           NaN
# 29                         11.76
# 30                          3.41
# 31                          0.77
# 32                          8.93
# 33                          2.10
# 34                          3.01
# 35                          8.11
# 36                           NaN

# %% [markdown]
# ### Analyse if there is any correlation of GDP per capita with dropout rates in education (primary, upper primary and secondary) for the year 2014-2015 for each state. Choose an appropriate plot to conduct this analysis.

# %%
df3.columns
# Out:
# Index(['1', 'Level of Education - State', 'Primary - 2012-2013',
#        'Primary - 2013-2014', 'Primary - 2014-2015',
#        'Upper Primary - 2012-2013', 'Upper Primary - 2013-2014',
#        'Upper Primary - 2014-2015', 'Secondary - 2012-2013',
#        'Secondary - 2013-2014', 'Secondary - 2014-2015',
#        'Senior Secondary - 2012-2013', 'Senior Secondary - 2013-2014',
#        'Senior Secondary - 2014-2015'],
#       dtype='object')

# %%
edu_df = df3[['Level of Education - State','Primary - 2014-2015','Upper Primary - 2014-2015','Secondary - 2014-2015']]

# %%
edu_df
# Out:
#    Level of Education - State  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0               A & N Islands                 0.51                       1.69
# 1              Andhra Pradesh                 6.72                       5.20
# 2           Arunachal Pradesh                10.82                       6.71
# 3                       Assam                15.36                      10.51
# 4                       Bihar                  NaN                       4.08
# 5                  Chandigarh                  NaN                       0.44
# 6                 Chhatisgarh                 2.91                       5.85
# 7        Dadra & Nagar Haveli                 1.47                       4.02
# 8                 Daman & Diu                 1.11                       3.11
# 9                       Delhi                  NaN                       0.76
# 10                        Goa                 0.73                       0.07
# 11                    Gujarat                 0.89                       6.41
# 12                    Haryana                 5.61                       5.81
# 13           Himachal Pradesh                 0.64                       0.87
# 14          Jammu and Kashmir                 6.79                       5.44
# 15                  Jharkhand                 5.48                       8.99
# 16                  Karnataka                 2.02                       3.85
# 17                     Kerala                  NaN                        NaN
# 18                Lakshadweep                  NaN                       2.78
# 19             Madhya Pradesh                 6.59                       9.20
# 20                Maharashtra                 1.26                       1.79
# 21                    Manipur                 9.66                       4.20
# 22                  Meghalaya                 9.46                       6.52
# 23                    Mizoram                10.10                       4.78
# 24                   Nagaland                 5.61                       7.92
# 25                     Odisha                 2.86                       3.81
# 26                 Puducherry                 0.37                       0.56
# 27                     Punjab                 3.05                       3.22
# 28                  Rajasthan                 5.02                       3.07
# 29                     Sikkim                 2.27                       1.57
# 30                 Tamil Nadu                  NaN                        NaN
# 31                  Telangana                 2.08                       2.30
# 32                    Tripura                 1.28                       1.99
# 33              Uttar Pradesh                 8.58                       2.70
# 34                 Uttrakhand                 4.04                       1.19
# 35                West Bengal                 1.47                       4.30
# 36                  All India                 4.13                       4.03
#
#     Secondary - 2014-2015
# 0                   9.870
# 1                  15.710
# 2                  17.110
# 3                  27.060
# 4                  25.900
# 5                     NaN
# 6                  21.260
# 7                  16.770
# 8                  32.270
# 9                  11.810
# 10                 11.150
# 11                 25.040
# 12                 15.890
# 13                  6.070
# 14                 17.280
# 15                 24.000
# 16                 26.180
# 17                 12.320
# 18                  6.763
# 19                 24.770
# 20                 12.870
# 21                 14.380
# 22                 20.520
# 23                 21.880
# 24                 18.230
# 25                 29.560
# 26                 12.190
# 27                  8.860
# 28                 13.480
# 29                 15.890
# 30                  8.100
# 31                 15.530
# 32                 28.420
# 33                 10.220
# 34                 10.400
# 35                 17.800
# 36                 17.060

# %%
edu_df.rename(columns={'Level of Education - State': 'State'}, inplace=True)
# Out:
# C:\Users\Layashree S\AppData\Local\Temp\ipykernel_3408\4056936380.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edu_df.rename(columns={'Level of Education - State': 'State'}, inplace=True)

# %%
# Merge the DataFrames on the 'state' column
merged_df = pd.merge(gdp_df, edu_df, on='State')
merged_df
# Out:
#    S.No.                   Item              State   2014-15  \
# 0     17  Per Capita GSDP (Rs.)  Arunachal Pradesh  112718.0
# 1     17  Per Capita GSDP (Rs.)              Assam   60621.0
# 2     17  Per Capita GSDP (Rs.)              Bihar   33954.0
# 3     17  Per Capita GSDP (Rs.)                Goa  271793.0
# 4     17  Per Capita GSDP (Rs.)            Gujarat  141263.0
# 5     17  Per Capita GSDP (Rs.)            Haryana  164077.0
# 6     17  Per Capita GSDP (Rs.)   Himachal Pradesh  147330.0
# 7     17  Per Capita GSDP (Rs.)          Jharkhand   62091.0
# 8     17  Per Capita GSDP (Rs.)          Karnataka  145141.0
# 9     17  Per Capita GSDP (Rs.)             Kerala  154778.0
# 10    17  Per Capita GSDP (Rs.)     Madhya Pradesh   62989.0
# 11    17  Per Capita GSDP (Rs.)        Maharashtra  152853.0
# 12    17  Per Capita GSDP (Rs.)            Manipur   58442.0
# 13    17  Per Capita GSDP (Rs.)          Meghalaya   76228.0
# 14    17  Per Capita GSDP (Rs.)            Mizoram   97687.0
# 15    17  Per Capita GSDP (Rs.)           Nagaland   89607.0
# 16    17  Per Capita GSDP (Rs.)             Odisha   73979.0
# 17    17  Per Capita GSDP (Rs.)             Punjab  126606.0
# 18    17  Per Capita GSDP (Rs.)          Rajasthan   84837.0
# 19    17  Per Capita GSDP (Rs.)             Sikkim  240274.0
# 20    17  Per Capita GSDP (Rs.)         Tamil Nadu  146503.0
# 21    17  Per Capita GSDP (Rs.)          Telangana  139035.0
# 22    17  Per Capita GSDP (Rs.)            Tripura   77358.0
# 23    17  Per Capita GSDP (Rs.)      Uttar Pradesh   49450.0
#
#     Primary - 2014-2015  Upper Primary - 2014-2015  Secondary - 2014-2015
# 0                 10.82                       6.71                  17.11
# 1                 15.36                      10.51                  27.06
# 2                   NaN                       4.08                  25.90
# 3                  0.73                       0.07                  11.15
# 4                  0.89                       6.41                  25.04
# 5                  5.61                       5.81                  15.89
# 6                  0.64                       0.87                   6.07
# 7                  5.48                       8.99                  24.00
# 8                  2.02                       3.85                  26.18
# 9                   NaN                        NaN                  12.32
# 10                 6.59                       9.20                  24.77
# 11                 1.26                       1.79                  12.87
# 12                 9.66                       4.20                  14.38
# 13                 9.46                       6.52                  20.52
# 14                10.10                       4.78                  21.88
# 15                 5.61                       7.92                  18.23
# 16                 2.86                       3.81                  29.56
# 17                 3.05                       3.22                   8.86
# 18                 5.02                       3.07                  13.48
# 19                 2.27                       1.57                  15.89
# 20                  NaN                        NaN                   8.10
# 21                 2.08                       2.30                  15.53
# 22                 1.28                       1.99                  28.42
# 23                 8.58                       2.70                  10.22

# %%
# Calculate correlation
correlation = merged_df[['2014-15', 'Primary - 2014-2015','Upper Primary - 2014-2015','Secondary - 2014-2015']].corr()
print("Correlation Matrix:")
print(correlation)

# Visualize the correlation with scatter plots
plt.figure(figsize=(15, 5))

for i, col in enumerate(['Primary - 2014-2015','Upper Primary - 2014-2015','Secondary - 2014-2015']):
    plt.subplot(1, 3, i + 1)
    sns.regplot(x='2014-15', y=col, data=merged_df)
    plt.title(f'GDP per Capita vs {col.capitalize()} Dropout')
    plt.xlabel('GDP per Capita')
    plt.ylabel(f'{col.capitalize()} Dropout (%)')

plt.tight_layout()
plt.show()
# Out:
# Correlation Matrix:
#                             2014-15  Primary - 2014-2015  \
# 2014-15                    1.000000            -0.573119
# Primary - 2014-2015       -0.573119             1.000000
# Upper Primary - 2014-2015 -0.523868             0.647634
# Secondary - 2014-2015     -0.449877             0.176070
#
#                            Upper Primary - 2014-2015  Secondary - 2014-2015
# 2014-15                                    -0.523868              -0.449877
# Primary - 2014-2015                         0.647634               0.176070
# Upper Primary - 2014-2015                   1.000000               0.523281
# Secondary - 2014-2015                       0.523281               1.000000

# %% [markdown]
# ### Write down the key insights you draw from this data:	Form at least one reasonable hypothesis for the observations from the data.

# %% [markdown]
# Hypothesis:
# "States with higher GDP per capita in 2014-15 exhibit lower dropout rates across all educational levels, with stronger effects in primary and upper primary education due to better infrastructure and early intervention programs."
#
# Supporting Observations:
# The moderate to weak negative correlations (-0.573, -0.524, -0.450) suggest that economic prosperity helps reduce dropout rates, but the impact diminishes at higher education levels.
# Strong positive interdependencies between dropout rates across education levels indicate that dropout prevention strategies need to address all levels holistically, especially during transitions.
# Recommendations for Analysis and Action:
# Focus on Transition Phases:
#
# Strengthen transition mechanisms between education levels, especially from upper primary to secondary, to minimize dropout effects cascading into higher levels.
# Policy Insights:
#
# States with higher GDP per capita may have better educational funding, but ensuring equitable resource allocation to less affluent regions is essential to reduce disparities.
# Further Analysis:
#
# Investigate other factors influencing dropout rates (e.g., gender disparities, rural-urban divides, teacher-student ratios).
# Explore qualitative factors, such as societal attitudes towards education and the impact of child labor.
